# %% [markdown]
# # ACL Pose Estimation

# %% [markdown]
# ## See sample image

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
# %matplotlib inline

subj = 'S26'
IMG_FILENAME = "/media/thomaskil/Data Disk Large/_data/acl/test_images/after_20181026/" + subj + "/cam1/000000.jpg"
topleft_x = 350
topleft_y = 200
bottom_right_x = 900
bottom_right_y = 500

im = cv2.imread(IMG_FILENAME)
im = cv2.cvtColor(im, cv2.COLOR_RGB2BGR)
cv2.rectangle(im, (topleft_x, topleft_y), (bottom_right_x, bottom_right_y), color=(255, 0, 0), thickness=3)
h,w = im.shape[:2]
print(im.shape)
plt.figure(figsize=(12, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.imshow(im)
plt.show()
# Out:
# (720, 1280, 3)

# %% [markdown]
# ## Run Yolo Example

# %%
import sys
# !python "../keras-yolo3/yolo3_one_file_to_detect_them_all.py"  \
        -w "/media/thomaskil/Data Disk Large/_data/acl/data/yolo3/yolo3.weights" \
        -i "/media/thomaskil/Data Disk Large/_data/acl/test_images/after_20181026/S26/cam1/000000.jpg"
# Out:
# Using TensorFlow backend.
# 2020-05-06 15:33:00.646941: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 15:33:00.672007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 15:33:00.672391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2020-05-06 15:33:00.672507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-06 15:33:00.673340: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %% [markdown]
# ## Draw Bounding Box in Images (contained in folder)

# %%
# !python "../keras-yolo3/predict.py" \
    -c "../keras-yolo3/config_acl.json" \
    -i "/media/thomaskil/Data Disk Large/_data/acl/data/yolo3/tmp/cam2_tmp/" \
    -o "/media/thomaskil/Data Disk Large/_data/acl/data/yolo3/tmp/cam2_tmp_pred/"
# Out:
# Using TensorFlow backend.
# 2020-05-06 18:30:51.205667: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-06 18:30:51.229325: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-06 18:30:51.229886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2020-05-06 18:30:51.230016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-06 18:30:51.230867: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %% [markdown]
# ## Generate the labels for acl
# This python code does the following
# 1. Find the test subject number ('S26', 'S27', etc)
# 2. Find the number of frame numbers (frame_idxs) in each camera (cam1, cam2, cam3, cam4)
# 3. For each frame idx, associates a bounding box

# %%
# !python generate-labels-npy-multiview-acl3d.py
# Out:
# Looking at how much pictures in camera: cam1
# Looking at how much pictures in camera: cam2
# Looking at how much pictures in camera: cam3
# Looking at how much pictures in camera: cam4
# > /media/thomaskil/Code Disk/GIT/ACL_PoseEstimation/thomas/generate-labels-npy-multiview-acl3d.py(215)<module>()
# -> if not os.path.isdir(camera_path):
# (Pdb)
# --KeyboardInterrupt--
# (Pdb)

# %%
python "../keras-yolo3/predict.py" -c "../keras-yolo3/config_acl.json" -i "/media/thomaskil/Data Disk Large/_data/acl/data/yolo3/tmp/cam2_tmp"
